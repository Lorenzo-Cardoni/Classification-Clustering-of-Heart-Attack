# %%
import pandas as pd

# Leggi il dataset dal file CSV
df = pd.read_csv('heart.csv')

df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# Modifiche Dataset Weather Temperature:
# Le temperature originali sono in gradi Kelvin, le converto tutte in gradi Celsius

# %%
import pandas as pd

# Load the dataset
file_path = 'Dataset Weather/temperature.csv'  # Replace with the actual path to your CSV file
df = pd.read_csv(file_path)

#Elimino la prima riga che è Null
df = df.drop(index=0)

# Convert temperatures from Kelvin to Celsius
# Assuming the first column is the datetime and should be excluded from the conversion
for column in df.columns[1:]:
    df[column] = (df[column] - 273.15).round(1) #ho arrotondato ad una cifra dopo la virgola

# Save the modified DataFrame back to a CSV file
output_path = 'Dataset Weather/temperature_new.csv'  # Replace with the desired output path
df.to_csv(output_path, index=False)

print(f"Conversion complete. The new file is saved as {output_path}.")
# Out:
# Conversion complete. The new file is saved as Dataset Weather/temperature_new.csv.

# %%
df
# Out:
#                   datetime  Vancouver   Portland  San Francisco   Seattle  \
# 0      2012-10-01 12:00:00        NaN        NaN            NaN       NaN
# 1      2012-10-01 13:00:00  11.480000   8.930000      16.330000  8.650000
# 2      2012-10-01 14:00:00  11.479041   8.933252      16.324993  8.647217
# 3      2012-10-01 15:00:00  11.476998   8.941866      16.310618  8.639833
# 4      2012-10-01 16:00:00  11.474955   8.950481      16.296243  8.632449
# ...                    ...        ...        ...            ...       ...
# 45248  2017-11-29 20:00:00        NaN   8.850000            NaN  7.670000
# 45249  2017-11-29 21:00:00        NaN   9.740000            NaN  8.500000
# 45250  2017-11-29 22:00:00        NaN  10.240000            NaN  9.600000
# 45251  2017-11-29 23:00:00        NaN   9.870000            NaN  9.810000
# 45252  2017-11-30 00:00:00        NaN   9.130000            NaN  9.890000
#
#        Los Angeles  San Diego  Las Vegas    Phoenix  Albuquerque  ...  \
# 0              NaN        NaN        NaN        NaN          NaN  ...
# 1        18.720000  18.380000  20.260000  23.450000    11.970000  ...
# 2        18.718186  18.383501  20.253141  23.458509    12.004558  ...
# 3        18.712844  18.393355  20.242177  23.481487    12.083952  ...
# 4        18.707503  18.403209  20.231213  23.504466    12.163345  ...
# ...            ...        ...        ...        ...          ...  ...
# 45248    20.400000  19.000000  16.390000  21.560000    12.570000  ...
# 45249    22.530000  19.590000  17.460000  22.440000    13.300000  ...
# 45250    22.810000  19.430000  18.190000  23.100000    13.290000  ...
# 45251    22.500000  19.460000  19.000000  24.000000    12.990000  ...
# 45252    21.780000  18.250000  18.490000  24.000000    11.550000  ...
#
#        Philadelphia   New York   Montreal     Boston  Beersheba  \
# 0               NaN        NaN        NaN        NaN        NaN
# 1         12.480000  15.070000  12.680000  14.020000  34.440000
# 2         12.513208  15.097676  12.684650  14.036092  34.440000
# 3         12.606824  15.176940  12.697790  14.081672  34.241513
# 4         12.700440  15.256203  12.710929  14.127251  33.995200
# ...             ...        ...        ...        ...        ...
# 45248     17.090000        NaN   1.980000  14.930000        NaN
# 45249     16.090000        NaN   0.980000  12.870000        NaN
# 45250     13.630000        NaN   0.330000  10.790000        NaN
# 45251     11.420000        NaN  -0.670000   9.020000        NaN
# 45252     10.270000        NaN  -1.350000   7.500000        NaN
#
#        Tel Aviv District      Eilat  Haifa  Nahariyya  Jerusalem
# 0                    NaN  35.950000    NaN        NaN        NaN
# 1              32.320000  37.430000  31.25      31.25      30.35
# 2              31.160000  37.345769  31.25      31.25      30.35
# 3              31.131841  37.261538  31.25      31.25      30.35
# 4              31.088015  37.177308  31.25      31.25      30.35
# ...                  ...        ...    ...        ...        ...
# 45248                NaN        NaN    NaN        NaN        NaN
# 45249                NaN        NaN    NaN        NaN        NaN
# 45250                NaN        NaN    NaN        NaN        NaN
# 45251                NaN        NaN    NaN        NaN        NaN
# 45252                NaN        NaN    NaN        NaN        NaN
#
# [45253 rows x 37 columns]
